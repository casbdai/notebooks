# %% [markdown]
# # Applied Textmining
#
# A short introduction in data processing for textual data and some basic applications for sentiment analysis, embeddings, and the OpenAI API

# %% [markdown]
# ## Basic Setup
#
# Importing required functions:

# %%
# we import pandas for reading in files
import pandas as pd

# we import the openai and the json packages to access the OpenAI "Responses" API
from openai import OpenAI
import json

# we import a standard textmining function for bag of words
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# Reading in the data:

# %%
corpus = pd.read_csv("https://github.com/casbdai/notebooks/raw/main/Module2/Textmining/fake_news_updated_label.csv")
corpus.head()

# %% [markdown]
# ## The Challenge of "Bag of Words" Textmining

# %% [markdown]
# ### Creating a Term-Document-Matrix

# %%
# Create a vocabulary of all unique words that contain a minimum of three letters
vectorizer = CountVectorizer(token_pattern='[a-zA-Z]{3,}')

# Count the Occurences of the word tokens
tdm = vectorizer.fit_transform(corpus['text'])

# Convert the TDM to a DataFrame for better readability
tdm_df = pd.DataFrame(tdm.toarray(), columns=vectorizer.get_feature_names_out())
tdm_df

# %% [markdown]
# ### Basic Sentiment Analysis

# %%
# Define the list of stemmed positive words for comparison
positive_words = ["correct", "good", "success"]

# Identify which of these positive words are present as columns in tdm_df using .loc and .isin()
matching_columns = tdm_df.columns[tdm_df.columns.isin(positive_words)]

# Calculate the positive sentiment score for each document by summing the counts of matching positive words
corpus['positive_sentiment_score'] = tdm_df.loc[:, matching_columns].sum(axis=1)
corpus['positive_sentiment_score']

# %% [markdown]
# ## Text Analysis with Large Language Models
#
# ### Creating Embeddings via OpenAI API

# %% [markdown]
# Please copy the API key from the learning management software in here:

# %%
OPENAI_API_KEY = "ENTER YOUR API KEY HERE"

# %% [markdown]
# Let's get two samples texts for which we want to get embeddings:

# %%
sample_text_1 = corpus.loc[1053,"text"]
sample_text_1

# %%
sample_text_2 = corpus.loc[1054,"text"]
sample_text_2

# %% [markdown]
# Let's define a function for sending the texts to the Open AI API and getting embeddings in return:

# %%
def get_embedding(text, model="text-embedding-ada-002"):
    local_client = OpenAI(api_key=OPENAI_API_KEY)
    response = local_client.embeddings.create(input=[text], model=model)
    return response.data[0].embedding

# %% [markdown]
# Getting a sample of embeddings:

# %%
sample_embedding = get_embedding(sample_text_1)
sample_embedding

# %% [markdown]
# ## Performing Sentiment Analysis with the OpenAI API

# %% [markdown]
# Select the model and the reasoning effort that we want to use:

# %%
model = "gpt-5.4"
# model = "gpt-4.1-mini"

# for gpt-5.4, select reasoning effort
reasoning_effort = "low" # alternatively try "medium", "high", or "none"

# %% [markdown]
# The following function sends texts to the OpenAI API and given a specific prompt such "Score the likelihood of a positive sentiment" it returns a numeric score reaching from 0 to 1. 0 reflects a low probability of positive sentiment and 1 a high propability.

# %%
client = OpenAI(api_key=OPENAI_API_KEY)

def score_text(text):

    try:
        request = {
            "model": model,
            "input": [
                {
                    "role": "system",
                    "content": (
                        prompt
                        + "Score the text with a likelihood between 0 (very low) and 1 (very high)."
                          "Return JSON only with the key 'score'."
                    ),
                },
                {
                    "role": "user",
                    "content": text[:400],
                },
            ],
            "text": {
                "format": {
                    "type": "json_schema",
                    "name": "score_response",
                    "schema": {
                        "type": "object",
                        "properties": {
                            "score": {
                                "type": "number",
                                "minimum": 0,
                                "maximum": 1,
                            }
                        },
                        "required": ["score"],
                        "additionalProperties": False,
                    },
                    "strict": True,
                }
            },
        }

        if model.startswith("gpt-5.4"):
            request["reasoning"] = {"effort": reasoning_effort}

        response = client.responses.create(**request)

        data = json.loads(response.output_text)
        return data["score"]

    except Exception as e:
        print("An unexpected error occurred:", e)
        return None

# %% [markdown]
# Let's score some text:

# %%
prompt = "Score the likelihood of a positive sentiment."

corpus.head()["text"].apply(score_text)

# %% [markdown]
# ## Predicing Fake News

# %% [markdown]
# You can pass any prompt you want. If you want another scoring method instead of a likelihood, adapt the text within the function.

# %%
prompt = "Score the likelihood of the text being fake news."

prediction = corpus.head()["text"].apply(score_text)
prediction

# %% [markdown]
# Compare to the actual label:

# %%
corpus.head()["label"]

# %% [markdown]
# You can also score your own news:

# %%
score_text("The University of St.Gallen is offering the coolest CAS executive education course in AI")

# %% [markdown]
# ## Few-shot prompting
#
# So far, we used **zero-shot prompting**, where the model only receives the instruction and the new text.
#
# With **few-shot prompting**, we also provide a few small examples of the task before the new text. Each example contains:
#
# - an **input** text
# - the expected **output**
#
# Here, the examples show fake news texts together with their fake-news likelihood score. This can help the model better understand how the scoring task should be performed.
#
# To apply the function to a dataframe column, we pass both the text and the examples:
#
# ```python
# prediction = corpus.head()["text"].apply(
#     score_text_few_shot,
#     args=(few_shot_examples,)
# )

# %%
model = "gpt-5.4"
# model = "gpt-4.1-mini"

# for gpt-5.4, select reasoning effort
reasoning_effort = "low" # alternatively try "medium", "high", or "none"

# Few-shot prompting with the same dataframe workflow as before
def score_text_few_shot(text, examples=None):

    if examples is None:
        examples = []

    messages = [
        {
            "role": "system",
            "content": (
                prompt
                + "Score the text with a likelihood between 0 and 1. "
                  "Return JSON only with the key 'score'."
            ),
        }
    ]

    for example in examples:
        messages.append(
            {"role": "user","content": example["input"],}
        )
        messages.append(
            {"role": "assistant","content": json.dumps(example["output"]),}
        )

    messages.append(
        {"role": "user","content": text[:400],}
    )

    try:
        request = {
            "model": model,
            "input": messages,
            "text": {
                "format": {
                    "type": "json_schema",
                    "name": "few_shot_score_response",
                    "schema": {
                        "type": "object",
                        "properties": {
                            "score": {
                                "type": "number",
                                "minimum": 0,
                                "maximum": 1,
                            }
                        },
                        "required": ["score"],
                        "additionalProperties": False,
                    },
                    "strict": True,
                }
            },
        }

        if model.startswith("gpt-5.4"):
            request["reasoning"] = {"effort": reasoning_effort}

        response = client.responses.create(**request)
        return json.loads(response.output_text)["score"]

    except Exception as e:
        print("An unexpected error occurred:", e)
        return None

# %% [markdown]
# Now, define some examples from a our dataset and check whether we can improve our predictions

# %%
prompt = "Score the likelihood of the text being fake news."

# importantly, we choose examples from a part of the dataset that we do not use to evaluate our scoring model
few_shot_examples = [
    {
        "input": sample_text_1,
        "output": {"score": 1.00} # We know from the data set that this is fake news
    },
    {
        "input": sample_text_2, # You can see the input by just creating a new cell and pasting this: corpus.loc[1054, "text"]
        "output": {"score": 0.00} # We know from the data set that this is real news
    },
]

prediction = corpus.head()["text"].apply(
    score_text_few_shot,
    args=(few_shot_examples,)
)

prediction
