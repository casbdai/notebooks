# %% [markdown]
# # Introduction to Textmining with NLTK
#
# A short introduction in data processing for textual data and some basic applications for sentiment analysis and

# %% [markdown]
# # Basic Setup
#
#
# Import nltk library for text processing and download some extensions that are required.

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
# we import a series of specific functions from the nltk package for processing the texts.
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer
from nltk import FreqDist

# we import pandas for reading in files
import pandas as pd

from openai import OpenAI
import json

# %% [markdown]
# ## Read in the data

# %%
corpus = pd.read_csv("https://github.com/casbdai/notebooks/raw/main/Module2/Textmining/fake_news_updated_label.csv")
corpus.head()

# %% [markdown]
# We extract the second document and save it as an object text.

# %%
text = corpus["text"][1]
print(text)

# %% [markdown]
# ## Pre-Processing Textual Data

# %% [markdown]
# ### Convert text to lower case:

# %%
lower_text = text.lower()
print (lower_text)

# %% [markdown]
# ### Tokenize text
#
# Break down text into tokens, i.e, breaking the sentences into single words for analysis.

# %%
word_tokens = nltk.word_tokenize(lower_text)
print (word_tokens)

# %% [markdown]
# We need a better tokenizer also "punctuation" and "numbers" are retained as tokens. Also, very short words are translated into tokens.

# %%
better_tokenizer = RegexpTokenizer(r'[a-zA-Z]{3,}')

# [a-zA-Z] means that only letters are retained as tokens
# {3,} means that only tokens with at least three characters are retained

# %%
word_tokens = better_tokenizer.tokenize(lower_text)
print(word_tokens)

# %% [markdown]
# ## Remove stop words
#
# Remove irrelevant words using nltk stop words like is,the,a etc from the sentences as they don’t carry any information.

# %%
stopword = stopwords.words('english')
stopword

# %% [markdown]
# For getting rid of stopwords, we must compare each token against the words in the stop words list. With can be easily done in a list comprehension. List comprehension are a common extension of "for-loops".
#
# A for loop that prints out every token:

# %%
for word in word_tokens:
    print(word)

# %% [markdown]
# Reformulating the for loop as a list comprehension. List comprehensions are considered to be very understandable and are thus used very frequently by pythonistas.

# %%
[word for word in word_tokens]

# %% [markdown]
# Extending our list comprehension such that only tokens are retained that are NOT on the stoplist.

# %%
clean_tokens = [word for word in word_tokens if word not in stopword]
print (clean_tokens)

# %% [markdown]
# ## Stemming
#
#
# Often we want to map the different forms of the same word to the same root word, e.g. "walks", "walking", "walked" should all be the same as "walk".

# %%
snowball_stemmer = SnowballStemmer('english')

stemmed_tokens = [snowball_stemmer.stem(word) for word in clean_tokens]
print(stemmed_tokens)

# %% [markdown]
# ## Get word frequency
#
# Counting the most frequently used words in a textdocument

# %%
freq = FreqDist(stemmed_tokens)
print (freq.most_common(5))

# %% [markdown]
# # Very Basic Sentiment Analysis
#
# Using a dictionairy of positive and negative words, we can now perform a very basic sentiment analysis

# %%
pos_sent = []

[pos_sent.append(1) for word in stemmed_tokens if word in ["correct", "good", "increas"] ]

sum(pos_sent)

# %%
neg_sent = []

[neg_sent.append(1) for word in stemmed_tokens if word in ["virus", "infect","gun"] ]

sum(neg_sent)

# %%
sum(pos_sent) - sum(neg_sent)

# %% [markdown]
# # Text Analysis with Large Language Models

# %%
client = OpenAI(api_key="ENTER YOUR API KEY HERE")

# %%
model = "gpt-5.4"
# model = "gpt-4.1-mini"

# for gpt-5.4, select reasoning effort
reasoning_effort = "low" # alternatively try "medium", "high", or "none"

def score_text(text):
    try:
        request = {
            "model": model,
            "input": [
                {
                    "role": "system",
                    "content": (
                        prompt
                        + "Score the text with a likelihood between 0 (very low) and 1 (very high)."
                          "Return JSON only with the key 'score'."
                    ),
                },
                {
                    "role": "user",
                    "content": text[:400],
                },
            ],
            "text": {
                "format": {
                    "type": "json_schema",
                    "name": "score_response",
                    "schema": {
                        "type": "object",
                        "properties": {
                            "score": {
                                "type": "number",
                                "minimum": 0,
                                "maximum": 1,
                            }
                        },
                        "required": ["score"],
                        "additionalProperties": False,
                    },
                    "strict": True,
                }
            },
        }

        if model.startswith("gpt-5.4"):
            request["reasoning"] = {"effort": reasoning_effort}

        response = client.responses.create(**request)

        data = json.loads(response.output_text)
        return data["score"]

    except Exception as e:
        print("An unexpected error occurred:", e)
        return None

# %%
prompt = "Score the likelihood of a positive sentiment."

corpus.head()["text"].apply(score_text)

# %% [markdown]
# ## Comparing Fake and Real News

# %% [markdown]
# You can pass any prompt you want. If you want another scoring method instead of a likelihood, adapt the text within the function.

# %%
prompt = "Score the likelihood of the text being fake news."

prediction = corpus.head()["text"].apply(score_text)
prediction

# %% [markdown]
# Compare to the actual label:

# %%
corpus.head()["label"]

# %% [markdown]
# ## Few-shot prompting
#
# So far, we used **zero-shot prompting**, where the model only receives the instruction and the new text.
#
# With **few-shot prompting**, we also provide a few small examples of the task before the new text. Each example contains:
#
# - an **input** text
# - the expected **output**
#
# Here, the examples show fake news texts together with their fake-news likelihood score. This can help the model better understand how the scoring task should be performed.
#
# To apply the function to a dataframe column, we pass both the text and the examples:
#
# ```python
# prediction = corpus.head()["text"].apply(
#     score_text_few_shot,
#     args=(few_shot_examples,)
# )

# %%
model = "gpt-5.4"
# model = "gpt-4.1-mini"

# for gpt-5.4, select reasoning effort
reasoning_effort = "low" # alternatively try "medium", "high", or "none"

# Few-shot prompting with the same dataframe workflow as before
def score_text_few_shot(text, examples=None):
    """
    Score one text for fake-news likelihood using few-shot prompting.

    Parameters
    ----------
    text : str
        The text to score.
    examples : list of dict, optional
        Few-shot examples in the format:
        [
            {"input": "...", "output": {"score": 0.12}},
            {"input": "...", "output": {"score": 0.91}},
        ]

    Returns
    -------
    float
        A score between 0.0 and 1.0
    """
    if examples is None:
        examples = []

    messages = [
        {
            "role": "system",
            "content": (
                prompt
                + "Score the text with a likelihood between 0 and 1. "
                  "Return JSON only with the key 'score'."
            ),
        }
    ]

    for example in examples:
        messages.append(
            {
                "role": "user",
                "content": example["input"],
            }
        )
        messages.append(
            {
                "role": "assistant",
                "content": json.dumps(example["output"]),
            }
        )

    messages.append(
        {
            "role": "user",
            "content": text[:400],
        }
    )

    try:
        request = {
            "model": model,
            "input": messages,
            "text": {
                "format": {
                    "type": "json_schema",
                    "name": "few_shot_score_response",
                    "schema": {
                        "type": "object",
                        "properties": {
                            "score": {
                                "type": "number",
                                "minimum": 0,
                                "maximum": 1,
                            }
                        },
                        "required": ["score"],
                        "additionalProperties": False,
                    },
                    "strict": True,
                }
            },
        }

        if model.startswith("gpt-5.4"):
            request["reasoning"] = {"effort": reasoning_effort}

        response = client.responses.create(**request)
        return json.loads(response.output_text)["score"]

    except Exception as e:
        print("An unexpected error occurred:", e)
        return None

# %%
prompt = "Score the likelihood of the text being fake news."

few_shot_examples = [
    {
        "input": "Breaking: Scientists confirm that drinking two cups of coffee per day is associated with improved concentration in adults.",
        "output": {"score": 0.08}
    },
    {
        "input": "Shocking discovery: Government agents have been hiding proof that the moon is made of artificial material built by aliens.",
        "output": {"score": 0.97}
    },
]

prediction = corpus.head()["text"].apply(
    score_text_few_shot,
    args=(few_shot_examples,)
)

prediction

# %% [markdown]
# Now, instead of inventing some examples, let's use actual examples from our dataset.

# %%
prompt = "Score the likelihood of the text being fake news."

# importantly, we choose examples from a part of the dataset that we do not use to evaluate our scoring model
few_shot_examples = [
    {
        "input": corpus.loc[1054, "text"], # You can see the input by just creating a new cell and pasting this: corpus.loc[1054, "text"]
        "output": {"score": 0.00} # We know from corpus.loc[1054, "label"] that this is real news
    },
    {
        "input": corpus.loc[1053, "text"],
        "output": {"score": 1.00} # We know from corpus.loc[1053, "label"] that this is fake news
    },
]

prediction = corpus.head()["text"].apply(
    score_text_few_shot,
    args=(few_shot_examples,)
)

prediction

# %%
evaluation_df = pd.DataFrame({
    "text": corpus.head()["text"],
    "label": corpus.head()["label"],
    "predicted score": prediction
})
evaluation_df
