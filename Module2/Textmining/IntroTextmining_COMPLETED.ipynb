# %% [markdown]
# # Introduction to Textmining with NLTK
#
# A short introduction in data processing for textual data and some basic applications for sentiment analysis and

# %% [markdown]
# # Basic Setup
#
#
# Install nltk library for text processing and download some extensions that are required. Also, we install the wordcloud library for plotting our results as wordcloud.

# %%
# !pip install nltk
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# !pip install openai
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.61.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)

# %%
# we import a series of specific functions from the nltk package for processing the texts.
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer
from nltk import FreqDist

# we import pandas for reading in files
import pandas as pd

from openai import OpenAI
import json
from time import sleep

# %% [markdown]
# ## Read in the data

# %%
corpus = pd.read_csv("https://github.com/casbdai/notebooks/raw/main/Module2/Textmining/fake_news.csv")
corpus.head()
# Out:
#                                                title  \
# 0  With French Socialists in Crisis, Manuel Valls...
# 1  All Donated Blood in U.S. Should Be Tested for...
# 2  Eight Immigration Victories Won for Americans ...
# 3  How To WATCH The Highly Anticipated ‘CLINTON C...
# 4  CNBC: China’s Secret Plan to Crush the U.S. Sp...
#
#                                                 text label
# 0  BOISSEUIL, France  —   A furious   Ducourtioux...  Fake
# 1  The Food and Drug Administration on Friday too...  Fake
# 2  Last year was a success for Americans who are ...  Fake
# 3  SHARE this link with everyone you know. EVERY ...  Real
# 4  In a feature on Tuesday, CNBC explained how th...  Fake

# %% [markdown]
# We extract the second document and save it as an object text.

# %%
text = corpus["text"][1]
print(text)
# Out:
# The Food and Drug Administration on Friday took steps to safeguard the nation’s blood supply from the Zika virus, calling for all blood banks to screen donations for the infection even in states where the virus is not circulating. The recommendations are an acknowledgment that sexual transmission may facilitate the spread of Zika even in areas where mosquitoes carrying the virus are not present. Officials also want to prepare for the possibility that clusters of local infection will continue to pop up in parts of the United States for years to come. “There could be multiple outbreaks of Zika happening outside the known current ones in South Florida, but because we are not actively looking they could be happening silently,” said Dr. Peter J. Hotez, the dean of the National School of Tropical Medicine at Baylor College of Medicine, who applauded the F. D. A. ’s move. Without federal funds, it is generally not possible for local health departments to conduct active surveillance for Zika virus in the blood or urine of patients with fever or rash, he added. “In some ways the inaction from Congress has forced the F. D. A. to adopt this position,” Dr. Hotez added. “They have no other choice. ” The agency urged blood centers to use one of two experimental tests intended to detect active infections, called nucleic acid tests, before releasing donated blood for use in transfusions. As an alternative, banks may decontaminate plasma and platelets with   pathogen reduction technology. But the recommendations are likely to pose a significant challenge for some blood banks and for the   labs that perform much of the blood screening nationwide, some experts said. Eleven states must put the new safeguards into place within four weeks. They include Alabama, Arizona, California, Georgia, Louisiana, New York and Texas, which have many residents who travel to   countries or are near an area that already has locally acquired   cases. Other states have 12 weeks to carry out the recommendations. “This is a bombshell, because this is extremely rapid introduction of a new test nationwide that’s almost unprecedented,” said Dr. Jeffrey McCullough, emeritus professor of laboratory medicine and pathology at the University of Minnesota Medical School. “To try to implement this, in four weeks, is really, really difficult. ” Yet the new safeguards also are necessary, Dr. McCullough said. Under current guidelines, it is too difficult to identify infected donors by “trying to sort out risky donors by history of where they’ve been or what they’ve exposed to. ” Nationwide, nearly 14 million units of whole blood and red blood cells are collected each year from about seven million donors. Every day, as many as 36, 000 units of red blood cells are given to patients, along with 7, 000 platelet units and 10, 000 units of plasma. Consistent screening of the blood supply is an enormous task. There are more than 11, 500 confirmed cases of Zika virus in states and territories, according to the C. D. C. Nearly 2, 500 of them are people in the continental United States who traveled abroad where   mosquitoes are circulating. More than 30 cases were acquired in Florida. Puerto Rico has been screening all blood donations since March. The Centers for Disease Control and Prevention in June found that a surprisingly high percentage of donors had signs of active infection with the Zika virus. The F. D. A. provisionally approved two screening tests for Zika in blood donations on an investigational basis in March and June respectively. The first is made by Roche Molecular Systems, and the second by a collaboration between Hologic Inc. and Grifols. Neither test is fully F. D. A approved yet, and the facilities using them are enrolled in a continuing study. As part of Roche’s investigation, four centralized testing labs that screen blood for multiple banks in the South have been “collecting and testing blood for weeks now,” said Tony Hardiman, who leads the blood screening operations  ...

# %% [markdown]
# ## Pre-Processing Textual Data

# %% [markdown]
# ### Convert text to lower case:

# %%
lower_text = text.lower()
print (lower_text)
# Out:
# the food and drug administration on friday took steps to safeguard the nation’s blood supply from the zika virus, calling for all blood banks to screen donations for the infection even in states where the virus is not circulating. the recommendations are an acknowledgment that sexual transmission may facilitate the spread of zika even in areas where mosquitoes carrying the virus are not present. officials also want to prepare for the possibility that clusters of local infection will continue to pop up in parts of the united states for years to come. “there could be multiple outbreaks of zika happening outside the known current ones in south florida, but because we are not actively looking they could be happening silently,” said dr. peter j. hotez, the dean of the national school of tropical medicine at baylor college of medicine, who applauded the f. d. a. ’s move. without federal funds, it is generally not possible for local health departments to conduct active surveillance for zika virus in the blood or urine of patients with fever or rash, he added. “in some ways the inaction from congress has forced the f. d. a. to adopt this position,” dr. hotez added. “they have no other choice. ” the agency urged blood centers to use one of two experimental tests intended to detect active infections, called nucleic acid tests, before releasing donated blood for use in transfusions. as an alternative, banks may decontaminate plasma and platelets with   pathogen reduction technology. but the recommendations are likely to pose a significant challenge for some blood banks and for the   labs that perform much of the blood screening nationwide, some experts said. eleven states must put the new safeguards into place within four weeks. they include alabama, arizona, california, georgia, louisiana, new york and texas, which have many residents who travel to   countries or are near an area that already has locally acquired   cases. other states have 12 weeks to carry out the recommendations. “this is a bombshell, because this is extremely rapid introduction of a new test nationwide that’s almost unprecedented,” said dr. jeffrey mccullough, emeritus professor of laboratory medicine and pathology at the university of minnesota medical school. “to try to implement this, in four weeks, is really, really difficult. ” yet the new safeguards also are necessary, dr. mccullough said. under current guidelines, it is too difficult to identify infected donors by “trying to sort out risky donors by history of where they’ve been or what they’ve exposed to. ” nationwide, nearly 14 million units of whole blood and red blood cells are collected each year from about seven million donors. every day, as many as 36, 000 units of red blood cells are given to patients, along with 7, 000 platelet units and 10, 000 units of plasma. consistent screening of the blood supply is an enormous task. there are more than 11, 500 confirmed cases of zika virus in states and territories, according to the c. d. c. nearly 2, 500 of them are people in the continental united states who traveled abroad where   mosquitoes are circulating. more than 30 cases were acquired in florida. puerto rico has been screening all blood donations since march. the centers for disease control and prevention in june found that a surprisingly high percentage of donors had signs of active infection with the zika virus. the f. d. a. provisionally approved two screening tests for zika in blood donations on an investigational basis in march and june respectively. the first is made by roche molecular systems, and the second by a collaboration between hologic inc. and grifols. neither test is fully f. d. a approved yet, and the facilities using them are enrolled in a continuing study. as part of roche’s investigation, four centralized testing labs that screen blood for multiple banks in the south have been “collecting and testing blood for weeks now,” said tony hardiman, who leads the blood screening operations  ...

# %% [markdown]
# ### Tokenize text
#
# Break down text into tokens, i.e, breaking the sentences into single words for analysis.

# %%
word_tokens = nltk.word_tokenize(lower_text)
print (word_tokens)
# Out:
# ['the', 'food', 'and', 'drug', 'administration', 'on', 'friday', 'took', 'steps', 'to', 'safeguard', 'the', 'nation', '’', 's', 'blood', 'supply', 'from', 'the', 'zika', 'virus', ',', 'calling', 'for', 'all', 'blood', 'banks', 'to', 'screen', 'donations', 'for', 'the', 'infection', 'even', 'in', 'states', 'where', 'the', 'virus', 'is', 'not', 'circulating', '.', 'the', 'recommendations', 'are', 'an', 'acknowledgment', 'that', 'sexual', 'transmission', 'may', 'facilitate', 'the', 'spread', 'of', 'zika', 'even', 'in', 'areas', 'where', 'mosquitoes', 'carrying', 'the', 'virus', 'are', 'not', 'present', '.', 'officials', 'also', 'want', 'to', 'prepare', 'for', 'the', 'possibility', 'that', 'clusters', 'of', 'local', 'infection', 'will', 'continue', 'to', 'pop', 'up', 'in', 'parts', 'of', 'the', 'united', 'states', 'for', 'years', 'to', 'come', '.', '“', 'there', 'could', 'be', 'multiple', 'outbreaks', 'of', 'zika', 'happening', 'outside', 'the', 'known', 'current', 'ones', 'in', 'south', 'florida', ',', 'but', 'because', 'we', 'are', 'not', 'actively', 'looking', 'they', 'could', 'be', 'happening', 'silently', ',', '”', 'said', 'dr.', 'peter', 'j.', 'hotez', ',', 'the', 'dean', 'of', 'the', 'national', 'school', 'of', 'tropical', 'medicine', 'at', 'baylor', 'college', 'of', 'medicine', ',', 'who', 'applauded', 'the', 'f.', 'd.', 'a', '.', '’', 's', 'move', '.', 'without', 'federal', 'funds', ',', 'it', 'is', 'generally', 'not', 'possible', 'for', 'local', 'health', 'departments', 'to', 'conduct', 'active', 'surveillance', 'for', 'zika', 'virus', 'in', 'the', 'blood', 'or', 'urine', 'of', 'patients', 'with', 'fever', 'or', 'rash', ',', 'he', 'added', '.', '“', 'in', 'some', 'ways', 'the', 'inaction', 'from', 'congress', 'has', 'forced', 'the', 'f.', 'd.', 'a.', 'to', 'adopt', 'this', 'position', ',', '”', 'dr.', 'hotez', 'added', '.', '“', 'they', 'have', 'no', 'other', 'choice', '.', '”', 'the', 'agency', 'urged', 'blood', 'centers', 'to', 'use', 'one', 'of', 'two', 'experimental', 'tests', 'intended', 'to', 'detect', 'active', 'infections', ',', 'called', 'nucleic', 'acid', 'tests', ',', 'before', 'releasing', 'donated', 'blood', 'for', 'use', 'in', 'transfusions', '.', 'as', 'an', 'alternative', ',', 'banks', 'may', 'decontaminate', 'plasma', 'and', 'platelets', 'with', 'pathogen', 'reduction', 'technology', '.', 'but', 'the', 'recommendations', 'are', 'likely', 'to', 'pose', 'a', 'significant', 'challenge', 'for', 'some', 'blood', 'banks', 'and', 'for', 'the', 'labs', 'that', 'perform', 'much', 'of', 'the', 'blood', 'screening', 'nationwide', ',', 'some', 'experts', 'said', '.', 'eleven', 'states', 'must', 'put', 'the', 'new', 'safeguards', 'into', 'place', 'within', 'four', 'weeks', '.', 'they', 'include', 'alabama', ',', 'arizona', ',', 'california', ',', 'georgia', ',', 'louisiana', ',', 'new', 'york', 'and', 'texas', ',', 'which', 'have', 'many', 'residents', 'who', 'travel', 'to', 'countries', 'or', 'are', 'near', 'an', 'area', 'that', 'already', 'has', 'locally', 'acquired', 'cases', '.', 'other', 'states', 'have', '12', 'weeks', 'to', 'carry', 'out', 'the', 'recommendations', '.', '“', 'this', 'is', 'a', 'bombshell', ',', 'because', 'this', 'is', 'extremely', 'rapid', 'introduction', 'of', 'a', 'new', 'test', 'nationwide', 'that', '’', 's', 'almost', 'unprecedented', ',', '”', 'said', 'dr.', 'jeffrey', 'mccullough', ',', 'emeritus', 'professor', 'of', 'laboratory', 'medicine', 'and', 'pathology', 'at', 'the', 'university', 'of', 'minnesota', 'medical', 'school', '.', '“', 'to', 'try', 'to', 'implement', 'this', ',', 'in', 'four', 'weeks', ',', 'is', 'really', ',', 'really', 'difficult', '.', '”', 'yet', 'the', 'new', 'safeguards', 'also', 'are', 'necessary', ',', 'dr.', 'mccullough', 'said', '.', 'under', 'current', 'guidelines', ',', 'it', 'is', 'too', 'difficult', 'to', 'identify', 'infected', 'donors', 'by', '“', 'trying', 'to', 'sort', 'out', 'risky', 'donors', 'by', 'history', 'of', 'where', 'they', '’', 've', 'been ...

# %% [markdown]
# We need a better tokenizer also "punctuation" and "numbers" are retained as tokens. Also, very short words are translated into tokens.

# %%
better_tokenizer = RegexpTokenizer(r'[a-zA-Z]{3,}')

# [a-zA-Z] means that only letters are retained as tokens
# {3,} means that only tokens with at least three characters are retained

# %%
word_tokens = better_tokenizer.tokenize(lower_text)
print(word_tokens)
# Out:
# ['the', 'food', 'and', 'drug', 'administration', 'friday', 'took', 'steps', 'safeguard', 'the', 'nation', 'blood', 'supply', 'from', 'the', 'zika', 'virus', 'calling', 'for', 'all', 'blood', 'banks', 'screen', 'donations', 'for', 'the', 'infection', 'even', 'states', 'where', 'the', 'virus', 'not', 'circulating', 'the', 'recommendations', 'are', 'acknowledgment', 'that', 'sexual', 'transmission', 'may', 'facilitate', 'the', 'spread', 'zika', 'even', 'areas', 'where', 'mosquitoes', 'carrying', 'the', 'virus', 'are', 'not', 'present', 'officials', 'also', 'want', 'prepare', 'for', 'the', 'possibility', 'that', 'clusters', 'local', 'infection', 'will', 'continue', 'pop', 'parts', 'the', 'united', 'states', 'for', 'years', 'come', 'there', 'could', 'multiple', 'outbreaks', 'zika', 'happening', 'outside', 'the', 'known', 'current', 'ones', 'south', 'florida', 'but', 'because', 'are', 'not', 'actively', 'looking', 'they', 'could', 'happening', 'silently', 'said', 'peter', 'hotez', 'the', 'dean', 'the', 'national', 'school', 'tropical', 'medicine', 'baylor', 'college', 'medicine', 'who', 'applauded', 'the', 'move', 'without', 'federal', 'funds', 'generally', 'not', 'possible', 'for', 'local', 'health', 'departments', 'conduct', 'active', 'surveillance', 'for', 'zika', 'virus', 'the', 'blood', 'urine', 'patients', 'with', 'fever', 'rash', 'added', 'some', 'ways', 'the', 'inaction', 'from', 'congress', 'has', 'forced', 'the', 'adopt', 'this', 'position', 'hotez', 'added', 'they', 'have', 'other', 'choice', 'the', 'agency', 'urged', 'blood', 'centers', 'use', 'one', 'two', 'experimental', 'tests', 'intended', 'detect', 'active', 'infections', 'called', 'nucleic', 'acid', 'tests', 'before', 'releasing', 'donated', 'blood', 'for', 'use', 'transfusions', 'alternative', 'banks', 'may', 'decontaminate', 'plasma', 'and', 'platelets', 'with', 'pathogen', 'reduction', 'technology', 'but', 'the', 'recommendations', 'are', 'likely', 'pose', 'significant', 'challenge', 'for', 'some', 'blood', 'banks', 'and', 'for', 'the', 'labs', 'that', 'perform', 'much', 'the', 'blood', 'screening', 'nationwide', 'some', 'experts', 'said', 'eleven', 'states', 'must', 'put', 'the', 'new', 'safeguards', 'into', 'place', 'within', 'four', 'weeks', 'they', 'include', 'alabama', 'arizona', 'california', 'georgia', 'louisiana', 'new', 'york', 'and', 'texas', 'which', 'have', 'many', 'residents', 'who', 'travel', 'countries', 'are', 'near', 'area', 'that', 'already', 'has', 'locally', 'acquired', 'cases', 'other', 'states', 'have', 'weeks', 'carry', 'out', 'the', 'recommendations', 'this', 'bombshell', 'because', 'this', 'extremely', 'rapid', 'introduction', 'new', 'test', 'nationwide', 'that', 'almost', 'unprecedented', 'said', 'jeffrey', 'mccullough', 'emeritus', 'professor', 'laboratory', 'medicine', 'and', 'pathology', 'the', 'university', 'minnesota', 'medical', 'school', 'try', 'implement', 'this', 'four', 'weeks', 'really', 'really', 'difficult', 'yet', 'the', 'new', 'safeguards', 'also', 'are', 'necessary', 'mccullough', 'said', 'under', 'current', 'guidelines', 'too', 'difficult', 'identify', 'infected', 'donors', 'trying', 'sort', 'out', 'risky', 'donors', 'history', 'where', 'they', 'been', 'what', 'they', 'exposed', 'nationwide', 'nearly', 'million', 'units', 'whole', 'blood', 'and', 'red', 'blood', 'cells', 'are', 'collected', 'each', 'year', 'from', 'about', 'seven', 'million', 'donors', 'every', 'day', 'many', 'units', 'red', 'blood', 'cells', 'are', 'given', 'patients', 'along', 'with', 'platelet', 'units', 'and', 'units', 'plasma', 'consistent', 'screening', 'the', 'blood', 'supply', 'enormous', 'task', 'there', 'are', 'more', 'than', 'confirmed', 'cases', 'zika', 'virus', 'states', 'and', 'territories', 'according', 'the', 'nearly', 'them', 'are', 'people', 'the', 'continental', 'united', 'states', 'who', 'traveled', 'abroad', 'where', 'mosquitoes', 'are', 'circulating', 'more', 'than', 'cases', 'were', 'acquired', 'florida', 'puerto', 'rico', 'has',  ...

# %% [markdown]
# ## Remove stop words
#
# Remove irrelevant words using nltk stop words like is,the,a etc from the sentences as they don’t carry any information.

# %%
stopword = stopwords.words('english')
stopword
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %% [markdown]
# For getting rid of stopwords, we must compare each token against the words in the stop words list. With can be easily done in a list comprehension. List comprehension are a common extension of "for-loops".
#
# A for loop that prints out every token:

# %%
for word in word_tokens:
    print(word)
# Out:
# the
# food
# and
# drug
# administration
# friday
# took
# steps
# safeguard
# the
# nation
# blood
# supply
# from
# the
# zika
# virus
# calling
# for
# all
# blood
# banks
# screen
# donations
# for
# the
# infection
# even
# states
# where
# the
# virus
# not
# circulating
# the
# recommendations
# are
# acknowledgment
# that
# sexual
# transmission
# may
# facilitate
# the
# spread
# zika
# even
# areas
# where
# mosquitoes
# carrying
# the
# virus
# are
# not
# present
# officials
# also
# want
# prepare
# for
# the
# possibility
# that
# clusters
# local
# infection
# will
# continue
# pop
# parts
# the
# united
# states
# for
# years
# come
# there
# could
# multiple
# outbreaks
# zika
# happening
# outside
# the
# known
# current
# ones
# south
# florida
# but
# because
# are
# not
# actively
# looking
# they
# could
# happening
# silently
# said
# peter
# hotez
# the
# dean
# the
# national
# school
# tropical
# medicine
# baylor
# college
# medicine
# who
# applauded
# the
# move
# without
# federal
# funds
# generally
# not
# possible
# for
# local
# health
# departments
# conduct
# active
# surveillance
# for
# zika
# virus
# the
# blood
# urine
# patients
# with
# fever
# rash
# added
# some
# ways
# the
# inaction
# from
# congress
# has
# forced
# the
# adopt
# this
# position
# hotez
# added
# they
# have
# other
# choice
# the
# agency
# urged
# blood
# centers
# use
# one
# two
# experimental
# tests
# intended
# detect
# active
# infections
# called
# nucleic
# acid
# tests
# before
# releasing
# donated
# blood
# for
# use
# transfusions
# alternative
# banks
# may
# decontaminate
# plasma
# and
# platelets
# with
# pathogen
# reduction
# technology
# but
# the
# recommendations
# are
# likely
# pose
# significant
# challenge
# for
# some
# blood
# banks
# and
# for
# the
# labs
# that
# perform
# much
# the
# blood
# screening
# nationwide
# some
# experts
# said
# eleven
# states
# must
# put
# the
# new
# safeguards
# into
# place
# within
# four
# weeks
# they
# include
# alabama
# arizona
# california
# georgia
# louisiana
# new
# york
# and
# texas
# which
# have
# many
# residents
# who
# travel
# countries
# are
# near
# area
# that
# already
# has
# locally
# acquired
# cases
# other
# states
# have
# weeks
# carry
# out
# the
# recommendations
# this
# bombshell
# because
# this
# extremely
# rapid
# introduction
# new
# test
# nationwide
# that
# almost
# unprecedented
# said
# jeffrey
# mccullough
# emeritus
# professor
# laboratory
# medicine
# and
# pathology
# the
# university
# minnesota
# medical
# school
# try
# implement
# this
# four
# weeks
# really
# really
# difficult
# yet
# the
# new
# safeguards
# also
# are
# necessary
# mccullough
# said
# under
# current
# guidelines
# too
# difficult
# identify
# infected
# donors
# trying
# sort
# out
# risky
# donors
# history
# where
# they
# been
# what
# they
# exposed
# nationwide
# nearly
# million
# units
# whole
# blood
# and
# red
# blood
# cells
# are
# collected
# each
# year
# from
# about
# seven
# million
# donors
# every
# day
# many
# units
# red
# blood
# cells
# are
# given
# patients
# along
# with
# platelet
# units
# and
# units
# plasma
# consistent
# screening
# the
# blood
# supply
# enormous
# task
# there
# are
# more
# than
# confirmed
# cases
# zika
# virus
# states
# and
# territories
# according
# the
# nearly
# them
# are
# people
# the
# continental
# united
# states
# who
# traveled
# abroad
# where
# mosquitoes
# are
# circulating
# more
# than
# cases
# were
# acquired
# florida
# puerto
# rico
# has
# been
# screening
# all
# blood
# donations
# since
# march
# the
# centers
# for
# disease
# control
# and
# prevention
# june
# found
# that
# surprisingly
# high
# percentage
# donors
# had
# signs
# active
# infection
# with
# the
# zika
# virus
# the
# provisionally
# approved
# two
# screening
# tests
# for
# zika
# blood
# donations
# investigational
# basis
# march
# and
# june
# respectively
# the
# first
# made
# roche
# molecular
# systems
# and
# the
# second
# collaboration
# between
# hologic
# inc
# and
# grifols
# neither
# test
# fully
# approved
# yet
# and
# the
# facilities
# using
# them
# are
# enrolled
# continuing
# study
# part
# roche
# investigation
# four
# centralized
# testing
# labs
# that
# screen
# blood
# for
# multiple
# banks
# the
# south
# have
# been
# collecting
# and
# testing
# blood
# for
# weeks
# now
# said
# tony
# hardiman
# who
# leads
# the
# blood
# screening
# operations
# roche
# for
# the
# states
# that
# need
# ready
# month
# said
# are
# pretty
# much
# locked
# and
# loaded
# our
# focus
# now
# what
# for
# the
# rest
# the
# country
# bring
# them
# weeks
# added
# officials
# blood
# systems
# which
# operates
# blood
# banks
# states
# said
# they
# will
# able
# test
# blood
# donations
# california
# and
# some
# southern
# states
# like
# mississippi
# month
# the
# company
# will
# then
# work
# getting
# sites
# the
# rocky
# mountain
# states
# operational
# said
# ralph
# vassallo
# the
# chief
# medical
# and
# scientific
# officer
# creative
# testing
# solutions
# large
# blood
# donor
# testing
# lab
# already
# using
# both
# experimental
# zika
# screening
# tests
# tampa
# the
# company
# has
# relied
# roche
# test
# since
# the
# zika
# outbreaks
# began
# county
# its
# dallas
# and
# phoenix
# outposts
# has
# installed
# two
# panther
# machines
# able
# screen
# tubes
# blood
# with
# the
# test
# case
# mosquitoes
# arrive
# along
# the
# gulf
# coast
# light
# friday
# recommendations
# officials
# said
# they
# will
# have
# train
# more
# employees
# use
# new
# tests
# and
# significantly
# scale
# test
# percent
# the
# blood
# supply
# order
# able
# that
# all
# states
# weeks
# are
# going
# need
# additional
# pieces
# equipment
# said
# marc
# pearce
# spokesman
# for
# more
# panthers
# and
# one
# more
# machine
# that
# runs
# the
# roche
# test
# asked
# conference
# call
# with
# reporters
# about
# funding
# the
# new
# safeguards
# peter
# marks
# the
# director
# the
# center
# for
# biologics
# evaluation
# and
# research
# said
# can
# speak
# the
# cost
# implementation
# this
# time
# hospitals
# may
# wind
# paying
# more
# for
# each
# unit
# blood
# because
# additional
# screening
# costs
# some
# experts
# said
# when
# hospitals
# hear
# this
# they
# will
# concerned
# that
# they
# could
# see
# cost
# increase
# more
# per
# unit
# vassallo
# said
# which
# roughly
# how
# much
# costs
# screen
# each
# unit
# for
# the
# zika
# contamination
# this
# month
# after
# the
# first
# cases
# local
# transmission
# miami
# were
# discovered
# some
# blood
# banks
# near
# zika
# hot
# zones
# florida
# began
# screening
# blood
# donations
# according
# marks
# one
# donation
# contaminated
# with
# the
# virus
# had
# been
# found
# recent
# weeks
# the
# state
# the
# bag
# contaminated
# blood
# was
# discarded
# the
# system
# worked
# correctly
# marks
# said

# %% [markdown]
# Reformulating the for loop as a list comprehension. List comprehensions are considered to be very understandable and are thus used very frequently by pythonistas.

# %%
[word for word in word_tokens]
# Out:
# ['the',
#  'food',
#  'and',
#  'drug',
#  'administration',
#  'friday',
#  'took',
#  'steps',
#  'safeguard',
#  'the',
#  'nation',
#  'blood',
#  'supply',
#  'from',
#  'the',
#  'zika',
#  'virus',
#  'calling',
#  'for',
#  'all',
#  'blood',
#  'banks',
#  'screen',
#  'donations',
#  'for',
#  'the',
#  'infection',
#  'even',
#  'states',
#  'where',
#  'the',
#  'virus',
#  'not',
#  'circulating',
#  'the',
#  'recommendations',
#  'are',
#  'acknowledgment',
#  'that',
#  'sexual',
#  'transmission',
#  'may',
#  'facilitate',
#  'the',
#  'spread',
#  'zika',
#  'even',
#  'areas',
#  'where',
#  'mosquitoes',
#  'carrying',
#  'the',
#  'virus',
#  'are',
#  'not',
#  'present',
#  'officials',
#  'also',
#  'want',
#  'prepare',
#  'for',
#  'the',
#  'possibility',
#  'that',
#  'clusters',
#  'local',
#  'infection',
#  'will',
#  'continue',
#  'pop',
#  'parts',
#  'the',
#  'united',
#  'states',
#  'for',
#  'years',
#  'come',
#  'there',
#  'could',
#  'multiple',
#  'outbreaks',
#  'zika',
#  'happening',
#  'outside',
#  'the',
#  'known',
#  'current',
#  'ones',
#  'south',
#  'florida',
#  'but',
#  'because',
#  'are',
#  'not',
#  'actively',
#  'looking',
#  'they',
#  'could',
#  'happening',
#  'silently',
#  'said',
#  'peter',
#  'hotez',
#  'the',
#  'dean',
#  'the',
#  'national',
#  'school',
#  'tropical',
#  'medicine',
#  'baylor',
#  'college',
#  'medicine',
#  'who',
#  'applauded',
#  'the',
#  'move',
#  'without',
#  'federal',
#  'funds',
#  'generally',
#  'not',
#  'possible',
#  'for',
#  'local',
#  'health',
#  'departments',
#  'conduct',
#  'active',
#  'surveillance',
#  'for',
#  'zika',
#  'virus',
#  'the',
#  'blood',
#  'urine',
#  'patients',
#  'with',
#  'fever',
#  'rash',
#  'added',
#  'some',
#  'ways',
#  'the',
#  'inaction',
#  'from',
#  'congress',
#  'has',
#  'forced',
#  'the',
#  'adopt',
#  'this',
#  'position',
#  'hotez',
#  'added',
#  'they',
#  'have',
#  'other',
#  'choice',
#  'the',
#  'agency',
#  'urged',
#  'blood',
#  'centers',
#  'use',
#  'one',
#  'two',
#  'experimental',
#  'tests',
#  'intended',
#  'detect',
#  'active',
#  'infections',
#  'called',
#  'nucleic',
#  'acid',
#  'tests',
#  'before',
#  'releasing',
#  'donated',
#  'blood',
#  'for',
#  'use',
#  'transfusions',
#  'alternative',
#  'banks',
#  'may',
#  'decontaminate',
#  'plasma',
#  'and',
#  'platelets',
#  'with',
#  'pathogen',
#  'reduction',
#  'technology',
#  'but',
#  'the',
#  'recommendations',
#  'are',
#  'likely',
#  'pose',
#  'significant',
#  'challenge',
#  'for',
#  'some',
#  'blood',
#  'banks',
#  'and',
#  'for',
#  'the',
#  'labs',
#  'that',
#  'perform',
#  'much',
#  'the',
#  'blood',
#  'screening',
#  'nationwide',
#  'some',
#  'experts',
#  'said',
#  'eleven',
#  'states',
#  'must',
#  'put',
#  'the',
#  'new',
#  'safeguards',
#  'into',
#  'place',
#  'within',
#  'four',
#  'weeks',
#  'they',
#  'include',
#  'alabama',
#  'arizona',
#  'california',
#  'georgia',
#  'louisiana',
#  'new',
#  'york',
#  'and',
#  'texas',
#  'which',
#  'have',
#  'many',
#  'residents',
#  'who',
#  'travel',
#  'countries',
#  'are',
#  'near',
#  'area',
#  'that',
#  'already',
#  'has',
#  'locally',
#  'acquired',
#  'cases',
#  'other',
#  'states',
#  'have',
#  'weeks',
#  'carry',
#  'out',
#  'the',
#  'recommendations',
#  'this',
#  'bombshell',
#  'because',
#  'this',
#  'extremely',
#  'rapid',
#  'introduction',
#  'new',
#  'test',
#  'nationwide',
#  'that',
#  'almost',
#  'unprecedented',
#  'said',
#  'jeffrey',
#  'mccullough',
#  'emeritus',
#  'professor',
#  'laboratory',
#  'medicine',
#  'and',
#  'pathology',
#  'the',
#  'university',
#  'minnesota',
#  'medical',
#  'school',
#  'try',
#  'implement',
#  'this',
#  'four',
#  'weeks',
#  'really',
#  'really',
#  'difficult',
#  'yet',
#  'the',
#  'new',
#  'safeguards',
#  'also',
#  'are',
#  'necessary',
#  'mccullough',
#  'said',
#  'under',
#  'current',
#  'guidelines',
#  'too',
#  'difficult',
#  'identify',
#  'infected',
#  'donors',
#  'trying',
#  'sort',
#  'out',
#  'risky',
#  'donors',
#  'history',
#  'where',
#  'they',
#  'been',
#  'what',
#  'they',
#  'exposed',
#  'nationwide',
#  'nearly',
#  'million',
#  'units',
#  'whole',
#  'blood',
#  'and',
#  'red',
#  'blood',
#  'cells',
#  'are',
#  'collected',
#  'each',
#  'year',
#  'from',
#  'about',
#  'seven',
#  'million',
#  'donors',
#  'every',
#  'day',
#  'many',
#  'units',
#  'red',
#  'blood',
#  'cells',
#  'are',
#  'given',
#  'patients',
#  'along',
#  'with',
#  'platelet',
#  'units',
#  'and',
#  'units',
#  'plasma',
#  'consistent',
#  'screening',
#  'the',
#  'blood',
#  'supply',
#  'enormous',
#  'task',
#  'there',
#  'are',
#  'more',
#  'than',
#  'confirmed',
#  'cases',
#  'zika',
#  'virus',
#  'states',
#  'and',
#  'territories',
#  'according',
#  'the',
#  'nearly',
#  'them',
#  'are',
#  'people',
#  'the',
#  'continental',
#  'united',
#  'states',
#  'who',
#  'traveled',
#  'abroad',
#  'where',
#  'mosquitoes',
#  'are',
#  'circulating',
#  'more',
#  'than',
#  'cases',
#  'were',
#  'acquired',
#  'florida',
#  'puerto',
#  'rico',
#  'has',
#  'been',
#  'screening',
#  'all',
#  'blood',
#  'donations',
#  'since',
#  'march',
#  'the',
#  'centers',
#  'for',
#  'disease',
#  'control',
#  'and',
#  'prevention',
#  'june',
#  'found',
#  'that',
#  'surprisingly',
#  'high',
#  'percentage',
#  'donors',
#  'had',
#  'signs',
#  'active',
#  'infection',
#  'with',
#  'the',
#  'zika',
#  'virus',
#  'the',
#  'provisionally',
#  'approved',
#  'two',
#  'screening',
#  'tests',
#  'for',
#  'zika',
#  'blood',
#  'donations',
#  'investigational',
#  'basis',
#  'march',
#  'and',
#  'june',
#  'respectively',
#  'the',
#  'first',
#  'made',
#  'roche',
#  'molecular',
#  'systems',
#  'and',
#  'the',
#  'second',
#  'collaboration',
#  'between',
#  'hologic',
#  'inc',
#  'and',
#  'grifols',
#  'neither',
#  'test',
#  'fully',
#  'approved',
#  'yet',
#  'and',
#  'the',
#  'facilities',
#  'using',
#  'them',
#  'are',
#  'enrolled',
#  'continuing',
#  'study',
#  'part',
#  'roche',
#  'investigation',
#  'four',
#  'centralized',
#  'testing',
#  'labs',
#  'that',
#  'screen',
#  'blood',
#  'for',
#  'multiple',
#  'banks',
#  'the',
#  'south',
#  'have',
#  'been',
#  'collecting',
#  'and',
#  'testing',
#  'blood',
#  'for',
#  'weeks',
#  'now',
#  'said',
#  'tony',
#  'hardiman',
#  'who',
#  'leads',
#  'the',
#  'blood',
#  'screening',
#  'operations',
#  'roche',
#  'for',
#  'the',
#  'states',
#  'that',
#  'need',
#  'ready',
#  'month',
#  'said',
#  'are',
#  'pretty',
#  'much',
#  'locked',
#  'and',
#  'loaded',
#  'our',
#  'focus',
#  'now',
#  'what',
#  'for',
#  'the',
#  'rest',
#  'the',
#  'country',
#  'bring',
#  'them',
#  'weeks',
#  'added',
#  'officials',
#  'blood',
#  'systems',
#  'which',
#  'operates',
#  'blood',
#  'banks',
#  'states',
#  'said',
#  'they',
#  'will',
#  'able',
#  'test',
#  'blood',
#  'donations',
#  'california',
#  'and',
#  'some',
#  'southern',
#  'states',
#  'like',
#  'mississippi',
#  'month',
#  'the',
#  'company',
#  'will',
#  'then',
#  'work',
#  'getting',
#  'sites',
#  'the',
#  'rocky',
#  'mountain',
#  'states',
#  'operational',
#  'said',
#  'ralph',
#  'vassallo',
#  'the',
#  'chief',
#  'medical',
#  'and',
#  'scientific',
#  'officer',
#  'creative',
#  'testing',
#  'solutions',
#  'large',
#  'blood',
#  'donor',
#  'testing',
#  'lab',
#  'already',
#  'using',
#  'both',
#  'experimental',
#  'zika',
#  'screening',
#  'tests',
#  'tampa',
#  'the',
#  'company',
#  'has',
#  'relied',
#  'roche',
#  'test',
#  'since',
#  'the',
#  'zika',
#  'outbreaks',
#  'began',
#  'county',
#  'its',
#  'dallas',
#  'and',
#  'phoenix',
#  'outposts',
#  'has',
#  'installed',
#  'two',
#  'panther',
#  'machines',
#  'able',
#  'screen',
#  'tubes',
#  'blood',
#  'with',
#  'the',
#  'test',
#  'case',
#  'mosquitoes',
#  'arrive',
#  'along',
#  'the',
#  'gulf',
#  'coast',
#  'light',
#  'friday',
#  'recommendations',
#  'officials',
#  'said',
#  'they',
#  'will',
#  'have',
#  'train',
#  'more',
#  'employees',
#  'use',
#  'new',
#  'tests',
#  'and',
#  'significantly',
#  'scale',
#  'test',
#  'percent',
#  'the',
#  'blood',
#  'supply',
#  'order',
#  'able',
#  'that',
#  'all',
#  'states',
#  'weeks',
#  'are',
#  'going',
#  'need',
#  'additional',
#  'pieces',
#  'equipment',
#  'said',
#  'marc',
#  'pearce',
#  'spokesman',
#  'for',
#  'more',
#  'panthers',
#  'and',
#  'one',
#  'more',
#  'machine',
#  'that',
#  'runs',
#  'the',
#  'roche',
#  'test',
#  'asked',
#  'conference',
#  'call',
#  'with',
#  'reporters',
#  'about',
#  'funding',
#  'the',
#  'new',
#  'safeguards',
#  'peter',
#  'marks',
#  'the',
#  'director',
#  'the',
#  'center',
#  'for',
#  'biologics',
#  'evaluation',
#  'and',
#  'research',
#  'said',
#  'can',
#  'speak',
#  'the',
#  'cost',
#  'implementation',
#  'this',
#  'time',
#  'hospitals',
#  'may',
#  'wind',
#  'paying',
#  'more',
#  'for',
#  'each',
#  'unit',
#  'blood',
#  'because',
#  'additional',
#  'screening',
#  'costs',
#  'some',
#  'experts',
#  'said',
#  'when',
#  'hospitals',
#  'hear',
#  'this',
#  'they',
#  'will',
#  'concerned',
#  'that',
#  'they',
#  'could',
#  'see',
#  'cost',
#  'increase',
#  'more',
#  'per',
#  'unit',
#  'vassallo',
#  'said',
#  'which',
#  'roughly',
#  'how',
#  'much',
#  'costs',
#  'screen',
#  'each',
#  'unit',
#  'for',
#  'the',
#  'zika',
#  'contamination',
#  'this',
#  'month',
#  'after',
#  'the',
#  'first',
#  'cases',
#  'local',
#  'transmission',
#  'miami',
#  'were',
#  'discovered',
#  'some',
#  'blood',
#  'banks',
#  'near',
#  'zika',
#  'hot',
#  'zones',
#  'florida',
#  'began',
#  'screening',
#  'blood',
#  'donations',
#  'according',
#  'marks',
#  'one',
#  'donation',
#  'contaminated',
#  'with',
#  'the',
#  'virus',
#  'had',
#  'been',
#  'found',
#  'recent',
#  'weeks',
#  'the',
#  'state',
#  'the',
#  'bag',
#  'contaminated',
#  'blood',
#  'was',
#  'discarded',
#  'the',
#  'system',
#  'worked',
#  'correctly',
#  'marks',
#  'said']

# %% [markdown]
# Extending our list comprehension such that only tokens are retained that are NOT on the stoplist.

# %%
clean_tokens = [word for word in word_tokens if word not in stopword]
print (clean_tokens)
# Out:
# ['food', 'drug', 'administration', 'friday', 'took', 'steps', 'safeguard', 'nation', 'blood', 'supply', 'zika', 'virus', 'calling', 'blood', 'banks', 'screen', 'donations', 'infection', 'even', 'states', 'virus', 'circulating', 'recommendations', 'acknowledgment', 'sexual', 'transmission', 'may', 'facilitate', 'spread', 'zika', 'even', 'areas', 'mosquitoes', 'carrying', 'virus', 'present', 'officials', 'also', 'want', 'prepare', 'possibility', 'clusters', 'local', 'infection', 'continue', 'pop', 'parts', 'united', 'states', 'years', 'come', 'could', 'multiple', 'outbreaks', 'zika', 'happening', 'outside', 'known', 'current', 'ones', 'south', 'florida', 'actively', 'looking', 'could', 'happening', 'silently', 'said', 'peter', 'hotez', 'dean', 'national', 'school', 'tropical', 'medicine', 'baylor', 'college', 'medicine', 'applauded', 'move', 'without', 'federal', 'funds', 'generally', 'possible', 'local', 'health', 'departments', 'conduct', 'active', 'surveillance', 'zika', 'virus', 'blood', 'urine', 'patients', 'fever', 'rash', 'added', 'ways', 'inaction', 'congress', 'forced', 'adopt', 'position', 'hotez', 'added', 'choice', 'agency', 'urged', 'blood', 'centers', 'use', 'one', 'two', 'experimental', 'tests', 'intended', 'detect', 'active', 'infections', 'called', 'nucleic', 'acid', 'tests', 'releasing', 'donated', 'blood', 'use', 'transfusions', 'alternative', 'banks', 'may', 'decontaminate', 'plasma', 'platelets', 'pathogen', 'reduction', 'technology', 'recommendations', 'likely', 'pose', 'significant', 'challenge', 'blood', 'banks', 'labs', 'perform', 'much', 'blood', 'screening', 'nationwide', 'experts', 'said', 'eleven', 'states', 'must', 'put', 'new', 'safeguards', 'place', 'within', 'four', 'weeks', 'include', 'alabama', 'arizona', 'california', 'georgia', 'louisiana', 'new', 'york', 'texas', 'many', 'residents', 'travel', 'countries', 'near', 'area', 'already', 'locally', 'acquired', 'cases', 'states', 'weeks', 'carry', 'recommendations', 'bombshell', 'extremely', 'rapid', 'introduction', 'new', 'test', 'nationwide', 'almost', 'unprecedented', 'said', 'jeffrey', 'mccullough', 'emeritus', 'professor', 'laboratory', 'medicine', 'pathology', 'university', 'minnesota', 'medical', 'school', 'try', 'implement', 'four', 'weeks', 'really', 'really', 'difficult', 'yet', 'new', 'safeguards', 'also', 'necessary', 'mccullough', 'said', 'current', 'guidelines', 'difficult', 'identify', 'infected', 'donors', 'trying', 'sort', 'risky', 'donors', 'history', 'exposed', 'nationwide', 'nearly', 'million', 'units', 'whole', 'blood', 'red', 'blood', 'cells', 'collected', 'year', 'seven', 'million', 'donors', 'every', 'day', 'many', 'units', 'red', 'blood', 'cells', 'given', 'patients', 'along', 'platelet', 'units', 'units', 'plasma', 'consistent', 'screening', 'blood', 'supply', 'enormous', 'task', 'confirmed', 'cases', 'zika', 'virus', 'states', 'territories', 'according', 'nearly', 'people', 'continental', 'united', 'states', 'traveled', 'abroad', 'mosquitoes', 'circulating', 'cases', 'acquired', 'florida', 'puerto', 'rico', 'screening', 'blood', 'donations', 'since', 'march', 'centers', 'disease', 'control', 'prevention', 'june', 'found', 'surprisingly', 'high', 'percentage', 'donors', 'signs', 'active', 'infection', 'zika', 'virus', 'provisionally', 'approved', 'two', 'screening', 'tests', 'zika', 'blood', 'donations', 'investigational', 'basis', 'march', 'june', 'respectively', 'first', 'made', 'roche', 'molecular', 'systems', 'second', 'collaboration', 'hologic', 'inc', 'grifols', 'neither', 'test', 'fully', 'approved', 'yet', 'facilities', 'using', 'enrolled', 'continuing', 'study', 'part', 'roche', 'investigation', 'four', 'centralized', 'testing', 'labs', 'screen', 'blood', 'multiple', 'banks', 'south', 'collecting', 'testing', 'blood', 'weeks', 'said', 'tony', 'hardiman', 'leads', 'blood', 'screening', 'operations', 'roche', 'states', 'need', 'ready', 'month', 'said', 'pretty', 'much', 'locked', 'loaded', 'focus', 'rest', 'country ...

# %% [markdown]
# ## Stemming
#
#
# Often we want to map the different forms of the same word to the same root word, e.g. "walks", "walking", "walked" should all be the same as "walk".

# %%
snowball_stemmer = SnowballStemmer('english')

stemmed_tokens = [snowball_stemmer.stem(word) for word in clean_tokens]
print(stemmed_tokens)
# Out:
# ['food', 'drug', 'administr', 'friday', 'took', 'step', 'safeguard', 'nation', 'blood', 'suppli', 'zika', 'virus', 'call', 'blood', 'bank', 'screen', 'donat', 'infect', 'even', 'state', 'virus', 'circul', 'recommend', 'acknowledg', 'sexual', 'transmiss', 'may', 'facilit', 'spread', 'zika', 'even', 'area', 'mosquito', 'carri', 'virus', 'present', 'offici', 'also', 'want', 'prepar', 'possibl', 'cluster', 'local', 'infect', 'continu', 'pop', 'part', 'unit', 'state', 'year', 'come', 'could', 'multipl', 'outbreak', 'zika', 'happen', 'outsid', 'known', 'current', 'one', 'south', 'florida', 'activ', 'look', 'could', 'happen', 'silent', 'said', 'peter', 'hotez', 'dean', 'nation', 'school', 'tropic', 'medicin', 'baylor', 'colleg', 'medicin', 'applaud', 'move', 'without', 'feder', 'fund', 'general', 'possibl', 'local', 'health', 'depart', 'conduct', 'activ', 'surveil', 'zika', 'virus', 'blood', 'urin', 'patient', 'fever', 'rash', 'ad', 'way', 'inact', 'congress', 'forc', 'adopt', 'posit', 'hotez', 'ad', 'choic', 'agenc', 'urg', 'blood', 'center', 'use', 'one', 'two', 'experiment', 'test', 'intend', 'detect', 'activ', 'infect', 'call', 'nucleic', 'acid', 'test', 'releas', 'donat', 'blood', 'use', 'transfus', 'altern', 'bank', 'may', 'decontamin', 'plasma', 'platelet', 'pathogen', 'reduct', 'technolog', 'recommend', 'like', 'pose', 'signific', 'challeng', 'blood', 'bank', 'lab', 'perform', 'much', 'blood', 'screen', 'nationwid', 'expert', 'said', 'eleven', 'state', 'must', 'put', 'new', 'safeguard', 'place', 'within', 'four', 'week', 'includ', 'alabama', 'arizona', 'california', 'georgia', 'louisiana', 'new', 'york', 'texa', 'mani', 'resid', 'travel', 'countri', 'near', 'area', 'alreadi', 'local', 'acquir', 'case', 'state', 'week', 'carri', 'recommend', 'bombshel', 'extrem', 'rapid', 'introduct', 'new', 'test', 'nationwid', 'almost', 'unpreced', 'said', 'jeffrey', 'mccullough', 'emeritus', 'professor', 'laboratori', 'medicin', 'patholog', 'univers', 'minnesota', 'medic', 'school', 'tri', 'implement', 'four', 'week', 'realli', 'realli', 'difficult', 'yet', 'new', 'safeguard', 'also', 'necessari', 'mccullough', 'said', 'current', 'guidelin', 'difficult', 'identifi', 'infect', 'donor', 'tri', 'sort', 'riski', 'donor', 'histori', 'expos', 'nationwid', 'near', 'million', 'unit', 'whole', 'blood', 'red', 'blood', 'cell', 'collect', 'year', 'seven', 'million', 'donor', 'everi', 'day', 'mani', 'unit', 'red', 'blood', 'cell', 'given', 'patient', 'along', 'platelet', 'unit', 'unit', 'plasma', 'consist', 'screen', 'blood', 'suppli', 'enorm', 'task', 'confirm', 'case', 'zika', 'virus', 'state', 'territori', 'accord', 'near', 'peopl', 'continent', 'unit', 'state', 'travel', 'abroad', 'mosquito', 'circul', 'case', 'acquir', 'florida', 'puerto', 'rico', 'screen', 'blood', 'donat', 'sinc', 'march', 'center', 'diseas', 'control', 'prevent', 'june', 'found', 'surpris', 'high', 'percentag', 'donor', 'sign', 'activ', 'infect', 'zika', 'virus', 'provision', 'approv', 'two', 'screen', 'test', 'zika', 'blood', 'donat', 'investig', 'basi', 'march', 'june', 'respect', 'first', 'made', 'roch', 'molecular', 'system', 'second', 'collabor', 'holog', 'inc', 'grifol', 'neither', 'test', 'fulli', 'approv', 'yet', 'facil', 'use', 'enrol', 'continu', 'studi', 'part', 'roch', 'investig', 'four', 'central', 'test', 'lab', 'screen', 'blood', 'multipl', 'bank', 'south', 'collect', 'test', 'blood', 'week', 'said', 'toni', 'hardiman', 'lead', 'blood', 'screen', 'oper', 'roch', 'state', 'need', 'readi', 'month', 'said', 'pretti', 'much', 'lock', 'load', 'focus', 'rest', 'countri', 'bring', 'week', 'ad', 'offici', 'blood', 'system', 'oper', 'blood', 'bank', 'state', 'said', 'abl', 'test', 'blood', 'donat', 'california', 'southern', 'state', 'like', 'mississippi', 'month', 'compani', 'work', 'get', 'site', 'rocki', 'mountain', 'state', 'oper', 'said', 'ralph', 'vassallo', 'chief', 'medic', 'scientif', 'offic', 'creativ', 'test', 'solut', 'larg', 'blood', 'donor', 'test', 'lab', 'a ...

# %% [markdown]
# ## Get word frequency
#
# Counting the most frequently used words in a textdocument

# %%
freq = FreqDist(stemmed_tokens)
print (freq.most_common(5))
# Out:
# [('blood', 26), ('test', 16), ('said', 14), ('screen', 12), ('state', 12)]

# %% [markdown]
# # Very Basic Sentiment Analysis
#
# Using a dictionairy of positive and negative words, we can now perform a very basic sentiment analysis

# %%
pos_sent = []

[pos_sent.append(1) for word in stemmed_tokens if word in ["correct", "good", "increas"] ]

sum(pos_sent)
# Out:
# 2

# %%
neg_sent = []

[neg_sent.append(1) for word in stemmed_tokens if word in ["virus", "infect","gun"] ]

sum(neg_sent)
# Out:
# 12

# %%
sum(pos_sent) - sum(neg_sent)
# Out:
# -10

# %% [markdown]
# # Text Analysis with Large Language Models

# %%
client = OpenAI(api_key="ENTER YOUR API KEY HERE")

# %%
def score_text(text):
  try:
    messages = [
        {
            "role": "system",
            "content": prompt + " Score the text with a likelihood between 0 (very low) and 1 (very high).\nReturn the score as JSON with the key 'score'. Make sure that only the JSON is returned."
        },
        {
            "role": "user",
            "content": text[:400]
        }
    ]
    sleep(1)
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        response_format={"type": "json_object"},
        temperature=0
    )
    return json.loads(response.choices[0].message.content)["score"]
  except Exception as e:
      print("An unexpected error occurred:", e)
      return None

# %%
prompt = "Score the likelihood of a positive sentiment."

corpus.head()["text"].apply(score_text)
# Out:
# 0    0.20
# 1    0.90
# 2    0.75
# 3    0.85
# 4    0.20
# Name: text, dtype: float64

# %% [markdown]
# ## Comparing Fake and Real News

# %% [markdown]
# You can pass any prompt you want. If you want another scoring method instead of a likelihood, adapt the text within the function.

# %%
prompt = "Score the likelihood of the text being fake news."

prediction = corpus.head()["text"].apply(score_text)
prediction
# Out:
# 0    0.10
# 1    0.10
# 2    0.80
# 3    0.95
# 4    0.20
# Name: text, dtype: float64

# %% [markdown]
# Compare to the actual label:

# %%
corpus.head()["label"]
# Out:
# 0    Fake
# 1    Fake
# 2    Fake
# 3    Real
# 4    Fake
# Name: label, dtype: object
