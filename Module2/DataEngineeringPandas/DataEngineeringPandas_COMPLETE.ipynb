# %% [markdown]
# # Hands on - Applied data engineering with Pandas

# %% [markdown]
# ### ...or creating a simple ETL process

# %% [markdown]
# In this hands-on session, we will again work with the data from the ACM case. However, in the last module some data scientists have already invested some time in data engineering and wrangling.
#
# Given our newly gained pandas skills, we now want to follow their path...

# %% [markdown]
# # 1) Importing Files

# %% [markdown]
# Import the survey data into pandas. However, the survey data is stored in three different sheets in the data file ("2023", "2024", and "2025"). Load them into pandas.

# %%
import pandas as pd

# %%
survey2023 = pd.read_excel("https://github.com/casbdai/notebooks/raw/main/Module2/DataEngineeringPandas/Pandas_TV_Survey_Data.xlsx", sheet_name="2023")

# %%
survey2024 = pd.read_excel("https://github.com/casbdai/notebooks/raw/main/Module2/DataEngineeringPandas/Pandas_TV_Survey_Data.xlsx", sheet_name="2024")

# %%
survey2025 = pd.read_excel("https://github.com/casbdai/notebooks/raw/main/Module2/DataEngineeringPandas/Pandas_TV_Survey_Data.xlsx", sheet_name="2025")

# %% [markdown]
# Have a look at the three dataframes. They all have the same sructure and identical variable names. Paste theme together into a new dataframe.

# %%
survey2023.head()

# %%
survey2023.info()

# %%
survey2024.info()

# %%
survey2025.info()

# %% [markdown]
# Combine files row-wise or column-wise
#
# *   set **axis=0** to row-wise combination
# *   set **axis=1** to column-wise combination

# %%
survey = pd.concat([survey2023, survey2024, survey2025], axis = 0)
survey.info()

# %% [markdown]
# Now also read in the intentionality results using an appropriate reading function. Watch out for the delimeter!

# %%
intentionality = pd.read_csv("https://raw.githubusercontent.com/casbdai/notebooks/main/Module2/DataEngineeringPandas/Pandas_TV_Intentionality_Data.csv", sep=";")
intentionality.info()

# %% [markdown]
# We need to fix the variable type of "date"

# %%
intentionality.date = pd.to_datetime(intentionality.date)
intentionality.info()

# %%
gtrends = pd.read_excel("https://github.com/casbdai/notebooks/raw/main/Module2/DataEngineeringPandas/Pandas_TV_GTrends_Data.xlsx")
gtrends.info()

# %% [markdown]
# # 2) Merging Files

# %% [markdown]
# Now after having loaded the data, we want to combine the data into one overarching data set. However, be aware that the data needs to be joined on three variables: Industry Ad Type, Program Name and date / Date Aired

# %% [markdown]
# Perform an inner join of the data.

# %%
inner =  pd.merge(survey, intentionality,
                  how="inner",
                  left_on=["Industry_Ad_Type", "Program_Name", "Date_Aired"],
                  right_on=["Industry_Ad_Type", "Program_Name", "date"])

inner.info()

# %% [markdown]
# Perform an left join of the data

# %%
left =  pd.merge(survey, intentionality,
                  how="left",
                  left_on=["Industry_Ad_Type", "Program_Name","Date_Aired"],
                  right_on=["Industry_Ad_Type", "Program_Name","date"])

left.info()

# %% [markdown]
# How many NaNs are introduced in the variable intentionality? (you can use .info() )

# %% [markdown]
# Number of NaN: __

# %% [markdown]
# Which joining method would you use for combining the two dataframe? Why?
#
# Your answer: __________________________

# %% [markdown]
# Add the gtrends to the merged dataset (left)

# %%
left =  pd.merge(left, gtrends,
                  how="left",
                  left_on=["Industry_Ad_Type", "Date_Aired"],
                  right_on=["Industry_Ad_Type", "date"])

left.info()

# %% [markdown]
# # 3) Dealing with NA

# %% [markdown]
# In order to practice our "dealing with missing data skills", we have to decided to go with an outer join.

# %% [markdown]
# Create a new dataframe in which you have removed all missing values:

# %%
acmdata = left.dropna()
acmdata.info()

# %% [markdown]
# Create a new dataframe in which you insert 0 into the missing data fields of appropriate variables.

# %%
acmdata_0 = left.fillna(value=0)
acmdata_0.info()

# %% [markdown]
# # 4) Tranforming Variables

# %% [markdown]
# In the following exercises, we use the acmdata dataframe!

# %% [markdown]
# Rename the variable "TV_Ad_Spend" into "Spend_in_000"

# %%
acmdata = acmdata.rename(columns={"TV_Ad_Spend": "Spend_in_000"})
acmdata.info()

# %% [markdown]
# Delete the Variable "date"

# %%
del(acmdata["date_y"])
acmdata.info()

# %%
acmdata = acmdata.drop("date_x", axis = 1)
acmdata.info()

# %% [markdown]
# Aggregate the acmdata data frame by "Industry_Ad_Type" using .mean()

# %%
acmdata.groupby("Industry_Ad_Type").mean(numeric_only=True)

# %% [markdown]
# Aggregate the acm dataframe by "Industry_Ad_Type" and "Program_Name" using .sum()

# %%
acmdata.groupby(["Industry_Ad_Type", "Program_Name"]).sum(numeric_only=True)

# %% [markdown]
# Again, aggregate the acmdata dataframe by "Industry_Ad_Type" and "Program_Name" using .sum(). However, you are only interested in the spend and impressions data

# %%
acmdata.groupby(["Industry_Ad_Type", "Program_Name"])[["Spend_in_000", "TV_Ad_Impressions"]].sum()

# %% [markdown]
# ### Meaningful plots: Combining aggregations and .plot()

# %% [markdown]
# For creating more meaningful and Tableau-like plots in python, you have to combine aggregations with the .plot() method

# %%
acmdata.groupby(["Date_Aired"])["Spend_in_000"].sum().plot()

# %% [markdown]
# a barplot of Spend by Program Name

# %%
acmdata.groupby(["Program_Name"])["Spend_in_000"].sum().plot(kind="bar")

# %% [markdown]
# # Writing Data File

# %% [markdown]
# Now, write the merged and tidied data file as excel

# %%
acmdata.to_excel("acmdata.xlsx", index=False)

# %%
from google.colab import files
files.download('acmdata.xlsx')

# %% [markdown]
# Or write the data into an SQL database

# %%
import sqlalchemy as db

engine = db.create_engine("sqlite:///cleaned_database")
engine.connect()

acmdata.to_sql('clean_acm_data', con=engine, if_exists="replace", index=False)

inspector = db.inspect(engine)
inspector.get_table_names()

# %%
files.download('cleaned_database')
